# %%
nombre = "luis"
texto = "Hola {nombre}".format(nombre=nombre)

# %%
print(f"hola {nombre} como estas")
# Out:
# 'Hola luis'

# %%
from random import randint

aleatorio = randint(1, 10)
aleatorio
# Out:
# 9
